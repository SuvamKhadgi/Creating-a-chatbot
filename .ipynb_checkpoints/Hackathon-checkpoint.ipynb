# %%
import speech_recognition as sr
import pyttsx3

# Initialize the recognizer and TTS engine
recognizer = sr.Recognizer()
engine = pyttsx3.init()

# Function to convert text to speech
def speak(text):
    engine.say(text)
    engine.runAndWait()

# Function to get a yes or no confirmation from the user
def get_confirmation(prompt):
    while True:
        speak(prompt)
        with sr.Microphone() as source:
            recognizer.adjust_for_ambient_noise(source)
            audio_data = recognizer.listen(source)
            try:
                response = recognizer.recognize_google(audio_data).lower()
                if 'yes' in response:
                    return True
                elif 'no' in response:
                    return False
                else:
                    speak("Please say yes or no.")
            except sr.UnknownValueError:
                speak("I did not understand that. Please try again.")
            except sr.RequestError as e:
                speak(f"Error with the speech recognition service; {e}")

# Function to get user input for a prompt and confirm it
def get_input(prompt):
    while True:
        speak(prompt)
        with sr.Microphone() as source:
            recognizer.adjust_for_ambient_noise(source)
            audio_data = recognizer.listen(source)
            try:
                input_text = recognizer.recognize_google(audio_data)
                speak(f"You said: {input_text}. Is that correct? Please say yes or no.")
                if get_confirmation("Is that correct?"):
                    return input_text
                else:
                    speak("Let's try again.")
            except sr.UnknownValueError:
                speak("I did not understand that. Please try again.")
            except sr.RequestError as e:
                speak(f"Error with the speech recognition service; {e}")

# Main process
def main():
    speak("Hello, I will first ask for your phone number.")
    phone_number = get_input("Please say your phone number.")
    speak("Thank you. Now I will ask for your email.")
    email = get_input("Please say your email address.")
    
    speak(f"Your phone number is {phone_number} and your email is {email}. Is that correct?")
    if get_confirmation("Is the provided information correct?"):
        print(f"Stored Phone Number: {phone_number}")
        print(f"Stored Email: {email}")
        speak("Thank you. Your information has been saved.")
    else:
        speak("Let's start over.")
        main()

main()
print("Program ended.")

# %%
import tkinter as tk
from PIL import Image, ImageTk
import cv2
import numpy as np

# Function to play video in Tkinter window
def play_video():
    # Capture video frames
    ret, frame = cap.read()
    if ret:
        # Convert frame to RGB format
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # Convert frame to PIL Image
        image = Image.fromarray(frame)
        # Convert PIL Image to ImageTk format
        image_tk = ImageTk.PhotoImage(image)
        
        # Update the canvas image
        canvas.create_image(0, 0, anchor=tk.NW, image=image_tk)
        canvas.image = image_tk
        
        # Call this function again after a delay
        root.after(10, play_video)
    else:
        # If video ends, release the capture object
        cap.release()

# Initialize Tkinter window
root = tk.Tk()
root.title("Tkinter Video Background")
root.geometry("800x600")

# Create a canvas to display video frames
canvas = tk.Canvas(root, width=800, height=600)
canvas.pack()

# Load video using OpenCV
cap = cv2.VideoCapture('C:/Users/rujan/Videos/Captures/output.avi')

# Start playing video
play_video()

# Start the Tkinter main loop
root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
import cv2
import numpy as np
import speech_recognition as sr
import pyttsx3

# Initialize the recognizer and TTS engine
recognizer = sr.Recognizer()
engine = pyttsx3.init()

# Initialize variables for controlling video playback
playing_video = False

# Function to play video in Tkinter window
def play_video():
    global playing_video
    if playing_video:
        # Capture video frames
        ret, frame = cap.read()
        if ret:
            # Convert frame to RGB format
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # Convert frame to PIL Image
            image = Image.fromarray(frame)
            # Convert PIL Image to ImageTk format
            image_tk = ImageTk.PhotoImage(image)
            
            # Update the canvas image
            canvas.create_image(0, 0, anchor=tk.NW, image=image_tk)
            canvas.image = image_tk
            
            # Call this function again after a delay
            root.after(10, play_video)
        else:
            # If video ends, release the capture object
            cap.release()

# Function to start playing the video
def start_video():
    global playing_video
    playing_video = True
    play_video()

# Function to stop playing the video
def stop_video():
    global playing_video
    playing_video = False

# Initialize Tkinter window
root = tk.Tk()
root.title("Tkinter Video Background")
root.geometry("800x600")

# Create a canvas to display video frames
canvas = tk.Canvas(root, width=800, height=600)
canvas.pack()

# Load video using OpenCV
cap = cv2.VideoCapture('C:/Users/rujan/Videos/Captures/output.avi')

def speak(text):
    start_video()
    engine.say(text)
    engine.runAndWait()
    stop_video()

print("Listening... Say 'stop' to end the program.")

# Function to recognize speech and respond
def recognize_and_respond():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Please speak now.")
        
        while True:
            try:
                # Listen for the user's input
                audio_data = recognizer.listen(source)
                print("Recognizing...")
                
                # Recognize the speech using Google Web Speech API
                text = recognizer.recognize_google(audio_data)
                print(f"You said: {text}")

                # Respond with speech
                if text.lower() == "stop":
                    speak("Stopping the program.")
                    break                    
                else:
                    speak(f"You said: {text}")

            except sr.UnknownValueError:
                print("Speech recognition could not understand the audio.")
                speak("I did not understand that. Please try again.")
            except sr.RequestError as e:
                print(f"Could not request results from the speech recognition service; {e}")
                speak("There was an error with the speech recognition service.")

# Start the recognition and response loop in a separate thread
import threading
recognize_thread = threading.Thread(target=recognize_and_respond)
recognize_thread.start()
 
# Start the Tkinter main loop
root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk
import cv2
import numpy as np
import speech_recognition as sr
import pyttsx3
import subprocess
import time
import requests
import threading
from queue import Queue

# Initialize the recognizer and TTS engine
recognizer = sr.Recognizer()
engine = pyttsx3.init()

# Initialize variables for controlling video playback
playing_video = False

# Initialize a queue for managing TTS requests
tts_queue = Queue()

# Function to play video in Tkinter window
def play_video():
    global playing_video
    if playing_video:
        # Capture video frames
        ret, frame = cap.read()
        if ret:
            # Convert frame to RGB format
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # Convert frame to PIL Image
            image = Image.fromarray(frame)
            # Convert PIL Image to ImageTk format
            image_tk = ImageTk.PhotoImage(image)
            
            # Update the canvas image
            canvas.create_image(0, 0, anchor=tk.NW, image=image_tk)
            canvas.image = image_tk
            
            # Call this function again after a delay
            root.after(10, play_video)
        else:
            # If video ends, release the capture object
            cap.release()

# Function to start playing the video
def start_video():
    global playing_video
    playing_video = True
    play_video()

# Function to stop playing the video
def stop_video():
    global playing_video
    playing_video = False

# Function to make the bot speak
def speak(text):
    tts_queue.put(text)

# Function to process the TTS queue
def process_tts_queue():
    while True:
        text = tts_queue.get()
        engine.say(text)
        engine.runAndWait()
        tts_queue.task_done()

# Start a thread to process the TTS queue
tts_thread = threading.Thread(target=process_tts_queue, daemon=True)
tts_thread.start()

# Function to recognize speech
def recognize_speech():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening for your question...")
        speak("Listening for your question...")
        audio_data = recognizer.listen(source)
        try:
            question = recognizer.recognize_google(audio_data)
            print(f"You said: {question}")
            return question
        except sr.UnknownValueError:
            print("Could not understand audio")
            speak("I could not understand what you said. Please try again.")
            return None
        except sr.RequestError as e:
            print(f"Could not request results; {e}")
            speak("There was an error with the speech recognition service.")
            return None

# Function to communicate with the Rasa server
def communicate_with_rasa(question):
    url = "http://localhost:5005/webhooks/rest/webhook"
    payload = {
        "sender": "user",
        "message": question
    }
    response = requests.post(url, json=payload)
    if response.status_code == 200:
        bot_responses = response.json()
        if bot_responses:
            return bot_responses[0]['text']
    return "Sorry, I couldn't get a response from the server."

# Function to run the Rasa shell
def run_rasa_shell():
    speak("Starting Rasa shell.")
    process = subprocess.Popen(["rasa", "run"], shell=True)
    time.sleep(5)  # Give Rasa some time to start
    speak("Rasa server is up and running.")
    return process

# Function to get a yes or no confirmation from the user
def get_confirmation(prompt):
    while True:
        speak(prompt)
        with sr.Microphone() as source:
            recognizer.adjust_for_ambient_noise(source)
            audio_data = recognizer.listen(source)
            try:
                response = recognizer.recognize_google(audio_data).lower()
                if 'yes' in response:
                    return True
                elif 'no' in response:
                    return False
                else:
                    speak("Please say yes or no.")
            except sr.UnknownValueError:
                speak("I did not understand that. Please try again.")
            except sr.RequestError as e:
                speak(f"Error with the speech recognition service; {e}")

# Function to get user input for a prompt and confirm it
def get_input(prompt):
    while True:
        speak(prompt)
        with sr.Microphone() as source:
            recognizer.adjust_for_ambient_noise(source)
            audio_data = recognizer.listen(source)
            try:
                input_text = recognizer.recognize_google(audio_data)
                speak(f"You said: {input_text}. Is that correct? Please say yes or no.")
                if get_confirmation("Is that correct?"):
                    return input_text
                else:
                    speak("Let's try again.")
            except sr.UnknownValueError:
                speak("I did not understand that. Please try again.")
            except sr.RequestError as e:
                speak(f"Error with the speech recognition service; {e}")

# Function to enroll user by asking for phone number and email
def enroll_user():
    speak("Hello, I will first ask for your phone number.")
    phone_number = get_input("Please say your phone number.")
    speak("Thank you. Now I will ask for your email.")
    email = get_input("Please say your email address.")
    
    speak(f"Your phone number is {phone_number} and your email is {email}. Is that correct?")
    if get_confirmation("Is the provided information correct?"):
        print(f"Stored Phone Number: {phone_number}")
        print(f"Stored Email: {email}")
        speak("Thank you. Your information has been saved.")
    else:
        speak("Let's start over.")
        enroll_user()

# Function to recognize speech and respond
def recognize_and_respond():
    while True:
        question = recognize_speech()
        if question:
            if "stop" in question.lower():
                speak("Stopping the program.")
                rasa_process.terminate()
                break
            elif "enroll" in question.lower():
                enroll_user()
            else:
                response = communicate_with_rasa(question)
                print(f"Bot: {response}")
                speak(response)
        time.sleep(1)  # Pause for a moment before the next iteration

# Initialize Tkinter window
root = tk.Tk()
root.title("Tkinter Video Background")
root.geometry("800x600")

# Create a canvas to display video frames
canvas = tk.Canvas(root, width=800, height=600)
canvas.pack()

# Load video using OpenCV
cap = cv2.VideoCapture('C:/Users/rujan/Videos/Captures/output.avi')

# Start the Rasa server
rasa_process = run_rasa_shell()

# Start the recognition and response loop in a separate thread
recognize_thread = threading.Thread(target=recognize_and_respond)
recognize_thread.start()

# Start the Tkinter main loop
root.mainloop()

print("Program ended.")

# %%
import tkinter as tk
from PIL import Image, ImageTk
import cv2
import numpy as np
import speech_recognition as sr
import pyttsx3
import subprocess
import time
import requests
import threading
import winsound  # Import the winsound module

# Initialize the recognizer and TTS engine
recognizer = sr.Recognizer()
engine = pyttsx3.init()

# Initialize variables for controlling video playback
playing_video = False

# Function to play video in Tkinter window
def play_video():
    global playing_video
    if playing_video:
        # Capture video frames
        ret, frame = cap.read()
        if ret:
            # Convert frame to RGB format
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # Convert frame to PIL Image
            image = Image.fromarray(frame)
            # Convert PIL Image to ImageTk format
            image_tk = ImageTk.PhotoImage(image)
            
            # Update the canvas image
            canvas.create_image(0, 0, anchor=tk.NW, image=image_tk)
            canvas.image = image_tk
            
            # Call this function again after a delay
            root.after(10, play_video)
        else:
            # If video ends, release the capture object
            cap.release()

# Function to start playing the video
def start_video():
    global playing_video
    playing_video = True
    play_video()

# Function to stop playing the video
def stop_video():
    global playing_video
    playing_video = False

# Function to make the bot speak
def speak(text):
    engine.say(text)
    engine.runAndWait()

# Function to play a sound indicating that the program is listening
def play_listening_sound():
    winsound.PlaySound(r"C:\Users\rujan\Downloads\voice-assistant-sound-name-unknown.wav", winsound.SND_FILENAME)

# Function to recognize speech
def recognize_speech():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening for your question...")
        play_listening_sound()  # Play the listening sound
        audio_data = recognizer.listen(source, timeout=300)
        try:
            question = recognizer.recognize_google(audio_data)
            print(f"You said: {question}")
            return question
        except sr.UnknownValueError:
            return None
        except sr.RequestError as e:
            print(f"Could not request results; {e}")
            return None

# Function to communicate with the Rasa server
def communicate_with_rasa(question):
    url = "http://localhost:5005/webhooks/rest/webhook"
    payload = {
        "sender": "user",
        "message": question
    }
    response = requests.post(url, json=payload)
    if response.status_code == 200:
        bot_responses = response.json()
        if bot_responses:
            return bot_responses[0]['text']
    return "Sorry, I couldn't get a response from the server."

# Function to run the Rasa shell
def run_rasa_shell():
    speak("Starting Rasa shell.")
    process = subprocess.Popen(["rasa", "run"], shell=True)
    time.sleep(5)  # Give Rasa some time to start
    speak("Rasa server is up and running.")
    return process

# Function to recognize speech and respond
def recognize_and_respond():
    while True:
        question = recognize_speech()
        if question:
            if "stop" in question.lower():
                speak("Stopping the program.")
                rasa_process.terminate()
                break
            else:
                response = communicate_with_rasa(question)
                print(f"Bot: {response}")
                speak(response)

# Initialize Tkinter window
root = tk.Tk()
root.title("Tkinter Video Background")
root.geometry("800x600")

# Create a canvas to display video frames
canvas = tk.Canvas(root, width=800, height=600)
canvas.pack()

# Load video using OpenCV
cap = cv2.VideoCapture(r'"C:\Users\rujan\Music\0-02-03-a74027f96903b52ad94a07031d41acfce56351bc07dc48dd7ceaa9b39cf188c9_7aef05336d191c9d.mp4"')

# Start the Rasa server
rasa_process = run_rasa_shell()

# Start the recognition and response loop in a separate thread
recognize_thread = threading.Thread(target=recognize_and_respond)
recognize_thread.start()

# Start the Tkinter main loop
root.mainloop()

print("Program ended.")

# %%
import tkinter as tk
from PIL import Image, ImageTk
import cv2
import numpy as np
import speech_recognition as sr
import pyttsx3
import subprocess
import time
import requests
import threading
import winsound

# Initialize the recognizer and TTS engine
recognizer = sr.Recognizer()
engine = pyttsx3.init()

# Initialize variables for controlling video playback
playing_video = False

# Function to play video in Tkinter window
def play_video():
    global playing_video, cap
    if playing_video:
        ret, frame = cap.read()
        if ret:
            # Resize frame to fit the canvas
            frame = cv2.resize(frame, (canvas_width, canvas_height))
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image = Image.fromarray(frame)
            image_tk = ImageTk.PhotoImage(image)
            canvas.create_image(0, 0, anchor=tk.NW, image=image_tk)
            canvas.image = image_tk
            root.after(10, play_video)
        else:
            cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
            play_video()

# Function to start playing the video
def start_video():
    global playing_video
    playing_video = True
    play_video()

# Function to stop playing the video
def stop_video():
    global playing_video
    playing_video = False

# Function to make the bot speak
def speak(text):
    engine.say(text)
    engine.runAndWait()

# Function to play a sound indicating that the program is listening
def play_listening_sound():
    winsound.PlaySound(r"C:\Users\rujan\Downloads\voice-assistant-sound-name-unknown.wav", winsound.SND_FILENAME)

# Function to recognize speech
def recognize_speech():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening for your question...")
        play_listening_sound()
        audio_data = recognizer.listen(source, timeout=300)
        try:
            question = recognizer.recognize_google(audio_data)
            print(f"You said: {question}")
            return question
        except sr.UnknownValueError:
            return None
        except sr.RequestError as e:
            print(f"Could not request results; {e}")
            return None

# Function to communicate with the Rasa server
def communicate_with_rasa(question):
    url = "http://localhost:5005/webhooks/rest/webhook"
    payload = {
        "sender": "user",
        "message": question
    }
    response = requests.post(url, json=payload)
    if response.status_code == 200:
        bot_responses = response.json()
        if bot_responses:
            return bot_responses[0]['text']
    return "Sorry, I couldn't get a response from the server."

# Function to run the Rasa shell
def run_rasa_shell():
    speak("Starting Rasa shell.")
    process = subprocess.Popen(["rasa", "run"], shell=True)
    time.sleep(5)
    speak("Rasa server is up and running.")
    return process

# Function to recognize speech and respond
def recognize_and_respond():
    while True:
        question = recognize_speech()
        if question:
            if "stop" in question.lower():
                speak("Stopping the program.")
                rasa_process.terminate()
                break
            else:
                response = communicate_with_rasa(question)
                print(f"Bot: {response}")
                speak(response)

# Initialize Tkinter window
root = tk.Tk()
root.title("Tkinter Video Background")
canvas_width = 800
canvas_height = 600
root.geometry(f"{canvas_width}x{canvas_height}")

# Create a canvas to display video frames
canvas = tk.Canvas(root, width=canvas_width, height=canvas_height)
canvas.pack()

# Load video using OpenCV
cap = cv2.VideoCapture(r"C:\Users\LEGION\Desktop\virtual_campus\Superlatives\captures\bot.webm")

# Start the Rasa server
rasa_process = run_rasa_shell()

# Start the recognition and response loop in a separate thread
recognize_thread = threading.Thread(target=recognize_and_respond)
recognize_thread.start()

# Start the video
start_video()

# Start the Tkinter main loop
root.mainloop()

print("Program ended.")
# Out:
# Listening for your question...

# %%
import tkinter as tk
from PIL import Image, ImageTk
import cv2
import numpy as np
import speech_recognition as sr
import pyttsx3
import subprocess
import time
import requests
import threading
import winsound

# Initialize the recognizer and TTS engine
recognizer = sr.Recognizer()
engine = pyttsx3.init()

# Initialize variables for controlling video playback
playing_video = False

# Function to play video in Tkinter window
def play_video():
    global playing_video, cap
    if playing_video:
        ret, frame = cap.read()
        if ret:
            # Resize frame to fit the canvas
            frame = cv2.resize(frame, (canvas_width, canvas_height))
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image = Image.fromarray(frame)
            image_tk = ImageTk.PhotoImage(image)
            canvas.create_image(0, 0, anchor=tk.NW, image=image_tk)
            canvas.image = image_tk
            root.after(10, play_video)
        else:
            cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
            play_video()

# Function to start playing the video
def start_video():
    global playing_video
    playing_video = True
    play_video()

# Function to stop playing the video
def stop_video():
    global playing_video
    playing_video = False

# Function to make the bot speak
def speak(text):
    engine.say(text)
    engine.runAndWait()

# Function to play a sound indicating that the program is listening
def play_listening_sound():
    winsound.PlaySound(r"C:\Users\rujan\Downloads\voice-assistant-sound-name-unknown.wav", winsound.SND_FILENAME)

# Function to recognize speech
def recognize_speech():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening for your question...")
        play_listening_sound()
        audio_data = recognizer.listen(source, timeout=300)
        try:
            question = recognizer.recognize_google(audio_data)
            print(f"You said: {question}")
            return question
        except sr.UnknownValueError:
            return None
        except sr.RequestError as e:
            print(f"Could not request results; {e}")
            return None

# Function to communicate with the Rasa server
def communicate_with_rasa(question):
    url = "http://localhost:5005/webhooks/rest/webhook"
    payload = {
        "sender": "user",
        "message": question
    }
    response = requests.post(url, json=payload)
    if response.status_code == 200:
        bot_responses = response.json()
        if bot_responses:
            return bot_responses[0]['text']
    return "Sorry, I couldn't get a response from the server."

# Function to run the Rasa shell
def run_rasa_shell():
    speak("Starting Rasa shell.")
    process = subprocess.Popen(["rasa", "run"], shell=True)
    time.sleep(5)
    speak("Rasa server is up and running.")
    return process

# Function to recognize speech and respond
def recognize_and_respond():
    while True:
        question = recognize_speech()
        if question:
            if "stop" in question.lower():
                speak("Stopping the program.")
                rasa_process.terminate()
                break
            else:
                #start_video()  # Start video when a question is asked
                response = communicate_with_rasa(question)
                #stop_video()  # Stop video after question is processed
                print(f"Bot: {response}")
                start_video()
                speak(response)
                stop_video()

# Initialize Tkinter window
root = tk.Tk()
root.title("Tkinter Video Background")
canvas_width = 800
canvas_height = 600
root.geometry(f"{canvas_width}x{canvas_height}")

# Create a canvas to display video frames
canvas = tk.Canvas(root, width=canvas_width, height=canvas_height)
canvas.pack()

# Load video using OpenCV
cap = cv2.VideoCapture(r"C:\Users\LEGION\Desktop\virtual_campus\Superlatives\captures\bot.webm")

# Start the Rasa server
rasa_process = run_rasa_shell()

# Start the recognition and response loop in a separate thread
recognize_thread = threading.Thread(target=recognize_and_respond)
recognize_thread.start()

# Initially start and immediately stop the video to initialize the canvas
start_video()
stop_video()

# Start the Tkinter main loop
root.mainloop()

print("Program ended.")
# Out:
# Listening for your question...
# Listening for your question...
# You said: hello
# Bot: Hey! How are you?
# Listening for your question...
# You said: what's available
# Bot: We offer the following courses: Science,Management,BIT,BBA,BIM,BBS,MBS,BSc.Microbiology,MSc Microbiology,MIT.
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# You said: hello hello hello hello hello hello hello
# Bot: Hey! How are you?
# Listening for your question...
# You said: I am ok thank you bye good night
# Bot: Bye
# Listening for your question...
# Listening for your question...
# Listening for your question...
# You said: is Shubham gay
# Bot: We provide the best quality of food services which is offordable
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# Listening for your question...
# You said: stop
# Program ended.

# %%
import cv2
import easyocr
from matplotlib import pyplot as plt
import numpy as np
import pyodbc
import os
import time
import pyodbc
import mysql.connector
import warnings
import speech_recognition as sr
import pyttsx3
from mysql.connector import Error
from PIL import Image
import base64

connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='khadgi986',
    database='kisthack'
)
cursor = connection.cursor()

citizenship_no = None
full_name = None
date_of_birth = None
birth_place = None
address = None

def  capture():
    

    # Define the path where you want to save the video
    output_dir = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures' 
    img_path = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures/final_frame.jpg' 
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    image_file = os.path.join(output_dir, 'final_frame.jpg')
    output_file = os.path.join(output_dir, 'output.avi')
    
    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Use 'XVID' codec
    out = cv2.VideoWriter(output_file, fourcc, 20.0, (640, 480))
    
    # Open a connection to the webcam
    cap = cv2.VideoCapture(0)
    
    if not cap.isOpened():
        print("Error: Could not open video device")
        exit()
    
    # Set the width and height of the frame
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
    
    # Countdown duration in seconds
    countdown_duration = 10
    start_time = time.time()
    
    # Define the rectangle parameters
    top_left = (50, 50)
    bottom_right = (600, 400)
    color = (255, 0, 0)  # Blue color in BGR
    thickness = 2  # Thickness of the rectangle border
    
    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            # Draw the rectangle on the frame
            cv2.rectangle(frame, top_left, bottom_right, color, thickness)
    
            # Calculate the elapsed time and countdown value
            elapsed_time = time.time() - start_time
            countdown_value = max(0, countdown_duration - int(elapsed_time))
    
            # Define the countdown text and its position
            countdown_text = str(countdown_value)
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 2
            font_color = (0, 255, 0)  # Green color in BGR
            font_thickness = 3
            text_size = cv2.getTextSize(countdown_text, font, font_scale, font_thickness)[0]
            text_x = (top_left[0] + bottom_right[0] - text_size[0]) // 2
            text_y = (top_left[1] + bottom_right[1] + text_size[1]) // 2
    
            # Put the countdown text on the frame
            cv2.putText(frame, countdown_text, (text_x, text_y), font, font_scale, font_color, font_thickness)
    
            # Write the frame to the output file
            out.write(frame)
    
            # Display the frame
            cv2.imshow('frame', frame)
    
            # Break the loop on 'q' key press or when countdown reaches zero
            if cv2.waitKey(1) & 0xFF == ord('q') or countdown_value == 0:
                if countdown_value == 0:
                    # Save the last frame within the rectangle as an image
                    roi = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                    cv2.imwrite(image_file, roi)
                break
        else:
            break
    
    # Release the webcam and file writer
    cap.release()
    out.release()
    
    # Close all OpenCV windows
    cv2.destroyAllWindows()

capture()
img_path = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures/final_frame.jpg' 
capture()
def ocrscnphoto():
    print()
    
citizenship_no = "17-01-77-05501"
full_name = "ASHOK SHAH"
date_of_birth = "2003 SEP 26"
birth_place = "Sonigama - 2,Dhanusha"
address = "Hansapur - 9,Dhanusha"

def prescanned():
    
    img = cv2.imread(image_path)
    
    reader = easyocr.Reader(['en'], gpu = True)
    text = reader.readtext(image_path)
    print(text)# Initialize an empty list to store the extracted strings
    extracted_strings = []
    
    # Iterate over each tuple in processed_data
    for item in text:
        # Extract the text from the tuple and append it to the list
        extracted_strings.append(item[1])
    
    # Print the extracted strings
    # for string in extracted_strings:
        # print(string)
    
    
    citizenship_no = extracted_strings[2][1:]
    sex = extracted_strings[3][5:]
    full_name = extracted_strings[5]
    date_of_birth = extracted_strings[7][-4:]+ " "+ extracted_strings[8][-3:]+ " "+ extracted_strings[9][-2:] 
    birth_place = extracted_strings[13]+ "-"+ extracted_strings[14][-2:]+ ","+ extracted_strings[11][10:]
    address = extracted_strings[18]+ "-"+ extracted_strings[19][-2:]+ ","+ extracted_strings[16][10:]
    
    
    print()
    print()
    print()
    # Print the extracted information
    print(f"Citizenship No: {citizenship_no}")
    print(f"Full Name: {full_name}")
    print(f"Date of Birth: {date_of_birth}")
    print(f"Birth Place: {birth_place}")
    print(f"Permanent Address: {address}")

img_path = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures/final_frame.jpg' 
print(f"Citizenship No: {citizenship_no}")
print(f"Full Name: {full_name}")
print(f"Date of Birth: {date_of_birth}")
print(f"Birth Place: {birth_place}")
print(f"Permanent Address: {address}")

    
email = "something@gm.com"
number = "9876543210"

def insertdata():
    connection = mysql.connector.connect(
        host='localhost',
        user='root',
        password='cpktnwt',
        database='kisthack'
    )
    cursor = connection.cursor()
    
    sql_insert_base64_query = """ INSERT INTO student
                                      ( name, citizenship_number, number, address, email, DOB, birthplace, photo) 
                                      VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"""
    
            
    with open(image_path, 'rb') as image_file:
        base64_image = base64.b64encode(image_file.read()).decode('utf-8')
    
            # Convert data into tuple format
    insert_base64_tuple = ( full_name, citizenship_no, number, address, email, date_of_birth, birth_place, base64_image)
    cursor.execute(sql_insert_base64_query, insert_base64_tuple)
    connection.commit()
    
    print("Record inserted successfully")
       
insertdata()
cursor.execute("SELECT * FROM student")
result = cursor.fetchall()

for row in result:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 115
#     112     # Close all OpenCV windows
#     113     cv2.destroyAllWindows()
# --> 115 capture()
#     116 img_path = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures/final_frame.jpg'
#     117 capture()
#
# Cell In[1], line 39, in capture()
#      36 img_path = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures/final_frame.jpg'
#      38 if not os.path.exists(output_dir):
# ---> 39     os.makedirs(output_dir)
#      41 image_file = os.path.join(output_dir, 'final_frame.jpg')
#      42 output_file = os.path.join(output_dir, 'output.avi')
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
#     [... skipping similar frames: makedirs at line 215 (2 times)]
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# PermissionError: [WinError 5] Access is denied: 'C:/Users/subad'

# %%
import cv2
import os
import time

def capture(output_dir='captures', countdown_duration=10):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    image_file = os.path.join(output_dir, 'final_frame.jpg')
    output_file = os.path.join(output_dir, 'output.avi')
    
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_file, fourcc, 20.0, (640, 480))
    
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Error: Could not open video device")
        return None
    
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
    
    start_time = time.time()
    top_left = (50, 50)
    bottom_right = (600, 400)
    color = (255, 0, 0)
    thickness = 2
    
    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            cv2.rectangle(frame, top_left, bottom_right, color, thickness)
            elapsed_time = time.time() - start_time
            countdown_value = max(0, countdown_duration - int(elapsed_time))
            countdown_text = str(countdown_value)
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 2
            font_color = (0, 255, 0)
            font_thickness = 3
            text_size = cv2.getTextSize(countdown_text, font, font_scale, font_thickness)[0]
            text_x = (top_left[0] + bottom_right[0] - text_size[0]) // 2
            text_y = (top_left[1] + bottom_right[1] + text_size[1]) // 2
            cv2.putText(frame, countdown_text, (text_x, text_y), font, font_scale, font_color, font_thickness)
            out.write(frame)
            cv2.imshow('frame', frame)
            if cv2.waitKey(1) & 0xFF == ord('q') or countdown_value == 0:
                if countdown_value == 0:
                    roi = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                    cv2.imwrite(image_file, roi)
                break
        else:
            break
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    return image_file

# %%
import easyocr

def ocr_scan(image_path):
    reader = easyocr.Reader(['en'], gpu=True)
    text = reader.readtext(image_path)
    extracted_strings = [item[1] for item in text]
    
    citizenship_no = extracted_strings[2][1:]
    sex = extracted_strings[3][5:]
    full_name = extracted_strings[5]
    date_of_birth = extracted_strings[7][-4:] + " " + extracted_strings[8][-3:] + " " + extracted_strings[9][-2:]
    birth_place = extracted_strings[13] + "-" + extracted_strings[14][-2:] + "," + extracted_strings[11][10:]
    address = extracted_strings[18] + "-" + extracted_strings[19][-2:] + "," + extracted_strings[16][10:]
    
    return {
        "citizenship_no": citizenship_no,
        "full_name": full_name,
        "date_of_birth": date_of_birth,
        "birth_place": birth_place,
        "address": address
    }

# %%
import mysql.connector
import base64

def insert_data_to_db(full_name, citizenship_no, number, address, email, date_of_birth, birth_place, image_path):
    connection = mysql.connector.connect(
        host='localhost',
        user='root',
        password='khadgi986',
        database='kisthack'
    )
    cursor = connection.cursor()
    
    sql_insert_base64_query = """INSERT INTO student
                                 (name, citizenship_number, number, address, email, DOB, birthplace, photo)
                                 VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"""
    
    with open(image_path, 'rb') as image_file:
        base64_image = base64.b64encode(image_file.read()).decode('utf-8')
    
    insert_base64_tuple = (full_name, citizenship_no, number, address, email, date_of_birth, birth_place, base64_image)
    cursor.execute(sql_insert_base64_query, insert_base64_tuple)
    connection.commit()
    cursor.close()
    connection.close()
    print("Record inserted successfully")

# %%
import cv2
import os
import time

def capture(output_dir='captures', countdown_duration=10):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    image_file = os.path.join(output_dir, 'final_frame.jpg')
    output_file = os.path.join(output_dir, 'output.avi')
    
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_file, fourcc, 20.0, (640, 480))
    
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Error: Could not open video device")
        return None
    
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
    
    start_time = time.time()
    top_left = (50, 50)
    bottom_right = (600, 400)
    color = (255, 0, 0)
    thickness = 2
    
    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            cv2.rectangle(frame, top_left, bottom_right, color, thickness)
            elapsed_time = time.time() - start_time
            countdown_value = max(0, countdown_duration - int(elapsed_time))
            countdown_text = str(countdown_value)
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 2
            font_color = (0, 255, 0)
            font_thickness = 3
            text_size = cv2.getTextSize(countdown_text, font, font_scale, font_thickness)[0]
            text_x = (top_left[0] + bottom_right[0] - text_size[0]) // 2
            text_y = (top_left[1] + bottom_right[1] + text_size[1]) // 2
            cv2.putText(frame, countdown_text, (text_x, text_y), font, font_scale, font_color, font_thickness)
            out.write(frame)
            cv2.imshow('frame', frame)
            if cv2.waitKey(1) & 0xFF == ord('q') or countdown_value == 0:
                if countdown_value == 0:
                    roi = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                    cv2.imwrite(image_file, roi)
                break
        else:
            break
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    return image_file

import easyocr

def ocr_scan(image_path):
    reader = easyocr.Reader(['en'], gpu=True)
    text = reader.readtext(image_path)
    extracted_strings = [item[1] for item in text]
    
    citizenship_no = extracted_strings[2][1:]
    sex = extracted_strings[3][5:]
    full_name = extracted_strings[5]
    date_of_birth = extracted_strings[7][-4:] + " " + extracted_strings[8][-3:] + " " + extracted_strings[9][-2:]
    birth_place = extracted_strings[13] + "-" + extracted_strings[14][-2:] + "," + extracted_strings[11][10:]
    address = extracted_strings[18] + "-" + extracted_strings[19][-2:] + "," + extracted_strings[16][10:]
    
    return {
        "citizenship_no": citizenship_no,
        "full_name": full_name,
        "date_of_birth": date_of_birth,
        "birth_place": birth_place,
        "address": address
    }



import mysql.connector
import base64

def insert_data_to_db(full_name, citizenship_no, number, address, email, date_of_birth, birth_place, image_path):
    connection = mysql.connector.connect(
        host='localhost',
        user='root',
        password='khadgi986',
        database='kisthack'
    )
    cursor = connection.cursor()
    
    sql_insert_base64_query = """INSERT INTO student
                                 (name, citizenship_number, number, address, email, DOB, birthplace, photo)
                                 VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"""
    
    with open(image_path, 'rb') as image_file:
        base64_image = base64.b64encode(image_file.read()).decode('utf-8')
    
    insert_base64_tuple = (full_name, citizenship_no, number, address, email, date_of_birth, birth_place, base64_image)
    cursor.execute(sql_insert_base64_query, insert_base64_tuple)
    connection.commit()
    cursor.close()
    connection.close()
    print("Record inserted successfully")



import tkinter as tk
from PIL import Image, ImageTk
import cv2
import threading
import speech_recognition as sr
import pyttsx3
import requests
import subprocess
import time
import winsound

recognizer = sr.Recognizer()
engine = pyttsx3.init()

def speak(text):
    engine.say(text)
    engine.runAndWait()

def play_listening_sound():
    winsound.PlaySound(r"C:\Users\LEGION\Downloads\voice-assistant-sound-name-unknown.wav", winsound.SND_FILENAME)

def recognize_speech():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening for your question...")
        play_listening_sound()
        audio_data = recognizer.listen(source, timeout=300)
        try:
            question = recognizer.recognize_google(audio_data)
            print(f"You said: {question}")
            return question
        except sr.UnknownValueError:
            return None
        except sr.RequestError as e:
            print(f"Could not request results; {e}")
            return None

def communicate_with_rasa(question):
    url = "http://localhost:5005/webhooks/rest/webhook"
    payload = {"sender": "user", "message": question}
    response = requests.post(url, json=payload)
    if response.status_code == 200:
        bot_responses = response.json()
        if bot_responses:
            return bot_responses[0]['text']
    return "Sorry, I couldn't get a response from the server."

def run_rasa_shell():
    speak("Starting Rasa shell.")
    process = subprocess.Popen(["rasa", "run"], shell=True)
    time.sleep(5)
    speak("Rasa server is up and running.")
    return process

def recognize_and_respond():
    while True:
        question = recognize_speech()
        if question:
            if "stop" in question.lower():
                speak("Stopping the program.")
                rasa_process.terminate()
                break
            else:
                response = communicate_with_rasa(question)
                print(f"Bot: {response}")
                if "capture" in question.lower():
                    image_path = capture()
                    if image_path:
                        ocr_result = ocr_scan(image_path)
                        speak(f"Scanned data: {ocr_result}")
                        insert_data_to_db(ocr_result['full_name'], ocr_result['citizenship_no'], "9876543210", ocr_result['address'], "something@gm.com", ocr_result['date_of_birth'], ocr_result['birth_place'], image_path)
                        speak("Data has been saved to the database.")
                else:
                    speak(response)

root = tk.Tk()
root.title("Tkinter Chatbot")
canvas_width = 800
canvas_height = 600
root.geometry(f"{canvas_width}x{canvas_height}")

canvas = tk.Canvas(root, width=canvas_width, height=canvas_height)
canvas.pack()

cap = cv2.VideoCapture(r"C:\Users\LEGION\Desktop\virtual_campus\Superlatives\captures\bot.webm")
rasa_process = run_rasa_shell()
recognize_thread = threading.Thread(target=recognize_and_respond)
recognize_thread.start()
root.mainloop()
print("Program ended.")
# Out:
# Listening for your question...
# You said: capture
# Bot: Sorry, I couldn't get a response from the server.
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Exception in thread Thread-5 (recognize_and_respond):
# Traceback (most recent call last):
#   File "C:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "C:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\LEGION\AppData\Local\Temp\ipykernel_1860\2606560234.py", line 179, in recognize_and_respond
#   File "C:\Users\LEGION\AppData\Local\Temp\ipykernel_1860\2606560234.py", line 66, in ocr_scan
# IndexError: list index out of range

# %%
import cv2
import easyocr
from matplotlib import pyplot as plt
import numpy as np
import pyodbc
import os
import time
import pyodbc
import mysql.connector
import warnings
import speech_recognition as sr
import pyttsx3
from mysql.connector import Error
from PIL import Image
import base64

connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='khadgi986',
    database='kisthack'
)
cursor = connection.cursor()

citizenship_no = None
full_name = None
date_of_birth = None
birth_place = None
address = None

def  capture():
    

    # Define the path where you want to save the video
    output_dir = r'C:\Users\LEGION\Desktop\virtual_campus\Superlatives\captures' 
    img_path = r'C:\Users\LEGION\Desktop\virtual_campus\Superlatives\captures\final_frame.jpg' 
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    image_file = os.path.join(output_dir, 'final_frame.jpg')
    output_file = os.path.join(output_dir, 'output.avi')
    
    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Use 'XVID' codec
    out = cv2.VideoWriter(output_file, fourcc, 20.0, (640, 480))
    
    # Open a connection to the webcam
    cap = cv2.VideoCapture(0)
    
    if not cap.isOpened():
        print("Error: Could not open video device")
        exit()
    
    # Set the width and height of the frame
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
    
    # Countdown duration in seconds
    countdown_duration = 10
    start_time = time.time()
    
    # Define the rectangle parameters
    top_left = (50, 50)
    bottom_right = (600, 400)
    color = (255, 0, 0)  # Blue color in BGR
    thickness = 2  # Thickness of the rectangle border
    
    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            # Draw the rectangle on the frame
            cv2.rectangle(frame, top_left, bottom_right, color, thickness)
    
            # Calculate the elapsed time and countdown value
            elapsed_time = time.time() - start_time
            countdown_value = max(0, countdown_duration - int(elapsed_time))
    
            # Define the countdown text and its position
            countdown_text = str(countdown_value)
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 2
            font_color = (0, 255, 0)  # Green color in BGR
            font_thickness = 3
            text_size = cv2.getTextSize(countdown_text, font, font_scale, font_thickness)[0]
            text_x = (top_left[0] + bottom_right[0] - text_size[0]) // 2
            text_y = (top_left[1] + bottom_right[1] + text_size[1]) // 2
    
            # Put the countdown text on the frame
            cv2.putText(frame, countdown_text, (text_x, text_y), font, font_scale, font_color, font_thickness)
    
            # Write the frame to the output file
            out.write(frame)
    
            # Display the frame
            cv2.imshow('frame', frame)
    
            # Break the loop on 'q' key press or when countdown reaches zero
            if cv2.waitKey(1) & 0xFF == ord('q') or countdown_value == 0:
                if countdown_value == 0:
                    # Save the last frame within the rectangle as an image
                    roi = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                    cv2.imwrite(image_file, roi)
                break
        else:
            break
    
    # Release the webcam and file writer
    cap.release()
    out.release()
    
    # Close all OpenCV windows
    cv2.destroyAllWindows()


img_path = r"C:\Users\LEGION\Desktop\virtual_campus\Superlatives\captures\final_frame.jpg"

def ocrscnphoto():
    print()

def ocrscanphoto():
    img_path = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures/final_frame.jpg'
    reader = easyocr.Reader(['en'], gpu = False)
    text = reader.readtext(img_path)
    
    
    print(text)
    
    
    
    
    # Initialize an empty list to store the extracted strings
    extracted_strings = []
    
    # Iterate over each tuple in processed_data
    for item in text:
        # Extract the text from the tuple and append it to the list
        extracted_strings.append(item[1])
    
    # Print the extracted strings
    for string in extracted_strings:
        print(string)
    
    
    citizenship_no = extracted_strings[2][1:]
    sex = extracted_strings[3][5:]
    full_name = extracted_strings[5]
    date_of_birth = extracted_strings[7][-4:]+ " "+ extracted_strings[8][-3:]+ " "+ extracted_strings[9][-2:] 
    birth_place = extracted_strings[13]+ "-"+ extracted_strings[14][-2:]+ ","+ extracted_strings[11][10:]
    address = extracted_strings[18]+ "-"+ extracted_strings[19][-2:]+ ","+ extracted_strings[16][10:]

ocrscnphoto()

citizenship_no = "17-01-77-05501"
full_name = "ASHOK SHAH"
date_of_birth = "2003 SEP 26"
birth_place = "Sonigama - 2,Dhanusha"
address = "Hansapur - 9,Dhanusha"

def prescanned():
    
    img = cv2.imread(image_path)
    
    reader = easyocr.Reader(['en'], gpu = True)
    text = reader.readtext(image_path)
    print(text)# Initialize an empty list to store the extracted strings
    extracted_strings = []
    
    # Iterate over each tuple in processed_data
    for item in text:
        # Extract the text from the tuple and append it to the list
        extracted_strings.append(item[1])
    
    # Print the extracted strings
    # for string in extracted_strings:
        # print(string)
    
    
    citizenship_no = extracted_strings[2][1:]
    sex = extracted_strings[3][5:]
    full_name = extracted_strings[5]
    date_of_birth = extracted_strings[7][-4:]+ " "+ extracted_strings[8][-3:]+ " "+ extracted_strings[9][-2:] 
    birth_place = extracted_strings[13]+ "-"+ extracted_strings[14][-2:]+ ","+ extracted_strings[11][10:]
    address = extracted_strings[18]+ "-"+ extracted_strings[19][-2:]+ ","+ extracted_strings[16][10:]
    
    
    print()
    print()
    print()
    # Print the extracted information
    print(f"Citizenship No: {citizenship_no}")
    print(f"Full Name: {full_name}")
    print(f"Date of Birth: {date_of_birth}")
    print(f"Birth Place: {birth_place}")
    print(f"Permanent Address: {address}")

img_path = r"C:\Users\LEGION\Desktop\virtual_campus\Superlatives\captures\final_frame.jpg"
print(f"Citizenship No: {citizenship_no}")
print(f"Full Name: {full_name}")
print(f"Date of Birth: {date_of_birth}")
print(f"Birth Place: {birth_place}")
print(f"Permanent Address: {address}")

    
email = "something@gm.com"
number = "9876543210"
image_path=r"C:\Users\LEGION\Downloads\back.jpg"
def insertdata():
    connection = mysql.connector.connect(
        host='localhost',
        user='root',
        password='khadgi986',
        database='kisthack'
    )
    cursor = connection.cursor()
    
    sql_insert_base64_query = """ INSERT INTO student
                                      ( name, citizenship_number, number, address, email, DOB, birthplace, photo) 
                                      VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"""
    
            
    with open(image_path, 'rb') as image_file:
        base64_image = base64.b64encode(image_file.read()).decode('utf-8')
    
            # Convert data into tuple format
    insert_base64_tuple = ( full_name, citizenship_no, number, address, email, date_of_birth, birth_place, base64_image)
    cursor.execute(sql_insert_base64_query, insert_base64_tuple)
    connection.commit()
    
    print("Record inserted successfully")
       
insertdata()
cursor.execute("SELECT * FROM student")
result = cursor.fetchall()

for row in result:
    print(row)
# Out:
# Citizenship No: 17-01-77-05501
# Full Name: ASHOK SHAH
# Date of Birth: 2003 SEP 26
# Birth Place: Sonigama - 2,Dhanusha
# Permanent Address: Hansapur - 9,Dhanusha
# Record inserted successfully
# (1, 'ASHOK SHAH', '17-01-77-05501', '9876543210', 'Hansapur - 9,Dhanusha', 'something@gm.com', '2003 SEP 26', 'Sonigama - 2,Dhanusha', b'...')
# (2, 'ASHOK SHAH', '17-01-77-05501', '9876543210', 'Hansapur - 9,Dhanusha', 'something@gm.com', '2003 SEP 26', 'Sonigama - 2,Dhanusha', b'...')
# (3, 'ASHOK SHAH', '17-01-77-05501', '9876543210', 'Hansapur - 9,Dhanusha', 'something@gm.com', '2003 SEP 26', 'Sonigama - 2,Dhanusha', b'...')
# (4, 'ASHOK SHAH', '17-01-77-05501', '9876543210', 'Hansapur - 9,Dhanusha', 'something@gm.com', '2003 SEP 26', 'Sonigama - 2,Dhanusha', b'...')
# (5, 'ASHOK SHAH', '17-01-77-05501', '9876543210', 'Hansapur - 9,Dhanusha', 'something@gm.com', '2003 SEP 26', 'Sonigama - 2,Dhanusha', b'...')
# (6, 'ASHOK SHAH', '17-01-77-05501', '9876543210', 'Hansapur - 9,Dhanusha', 'something@gm.com', '2003 SEP 26', 'Sonigama - 2,Dhanusha', b'...')
# (7, 'ASHOK SHAH', '17-01-77-05501', '9876543210', 'Hansapur - 9,Dhanusha', 'something@gm.com', '2003 SEP 26', 'Sonigama - 2,Dhanusha', b'...')

# %%
import tkinter as tk
from PIL import Image, ImageTk
import cv2
import threading
import speech_recognition as sr
import pyttsx3
import requests
import subprocess
import time
import winsound

recognizer = sr.Recognizer()
engine = pyttsx3.init()
# Initialize variables for controlling video playback
playing_video = False

# Function to play video in Tkinter window
def play_video():
    global playing_video, cap
    if playing_video:
        ret, frame = cap.read()
        if ret:
            # Resize frame to fit the canvas
            frame = cv2.resize(frame, (canvas_width, canvas_height))
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image = Image.fromarray(frame)
            image_tk = ImageTk.PhotoImage(image)
            canvas.create_image(0, 0, anchor=tk.NW, image=image_tk)
            canvas.image = image_tk
            root.after(10, play_video)
        else:
            cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
            play_video()

# Function to start playing the video
def start_video():
    global playing_video
    playing_video = True
    play_video()

# Function to stop playing the video
def stop_video():
    global playing_video
    playing_video = False

def speak(text):
    engine.say(text)
    engine.runAndWait()

def play_listening_sound():
    winsound.PlaySound(r"C:\Users\LEGION\Downloads\voice-assistant-sound-name-unknown.wav", winsound.SND_FILENAME)

def recognize_speech():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening for your question...")
        play_listening_sound()
        audio_data = recognizer.listen(source, timeout=300)
        try:
            question = recognizer.recognize_google(audio_data)
            print(f"You said: {question}")
            return question
        except sr.UnknownValueError:
            return None
        except sr.RequestError as e:
            print(f"Could not request results; {e}")
            return None

def communicate_with_rasa(question):
    url = "http://localhost:5005/webhooks/rest/webhook"
    payload = {"sender": "user", "message": question}
    response = requests.post(url, json=payload)
    if response.status_code == 200:
        bot_responses = response.json()
        if bot_responses:
            return bot_responses[0]['text']
    return "Sorry, I couldn't get a response from the server."

def run_rasa_shell():
    speak("Starting Rasa shell.")
    process = subprocess.Popen(["rasa", "run"], shell=True)
    time.sleep(5)
    speak("Rasa server is up and running.")
    return process

def enroll_user():
    speak("Hello, I will first ask for your phone number.")
    phone_number = get_input("Please say your phone number.")
    speak("Thank you. Now I will ask for your email.")
    email = get_input("Please say your email address.")

time.sleep(1)
def recognize_and_respond():
    while True:
        question = recognize_speech()
        if question:
            if "stop" in question.lower():
                speak("Stopping the program.")
                rasa_process.terminate()
                break
            elif "enroll" in question.lower():
                enroll_user()
            else:
                response = communicate_with_rasa(question)
                print(f"Bot: {response}")
                if "capture" in question.lower():
                    image_path = capture()
                    speak("Data has been saved to the database.")
                    if image_path:
                        ocr_result = ocr_scan(image_path)
                        speak(f"Scanned data: {ocr_result}")
                        insert_data_to_db(ocr_result['full_name'], ocr_result['citizenship_no'], "9876543210", ocr_result['address'], "something@gm.com", ocr_result['date_of_birth'], ocr_result['birth_place'], image_path)
                        speak("Data has been saved to the database.")
                else:
                    start_video()
                    speak(response)
                    stop_video()

root = tk.Tk()
root.title("Tkinter Chatbot")
canvas_width = 800
canvas_height = 600
root.geometry(f"{canvas_width}x{canvas_height}")

canvas = tk.Canvas(root, width=canvas_width, height=canvas_height)
canvas.pack()

cap = cv2.VideoCapture(r"C:\Users\LEGION\Desktop\New folder\Superlatives\captures\bot.webm")
# cap = cv2.VideoCapture(r"C:\Users\LEGION\Desktop\New folder\Superlatives\captures\bot.mp4")
rasa_process = run_rasa_shell()
recognize_thread = threading.Thread(target=recognize_and_respond)
recognize_thread.start()
start_video()
root.mainloop()
print("Program ended.")
# Out:
# Listening for your question...
# You said: hello
# Bot: Hey! How are you?
# Listening for your question...
# Listening for your question...
# You said: Andrew
# Bot: Great, carry on! Ask any thing about college.
# Listening for your question...
# You said: enroll
# Exception in thread Thread-9 (recognize_and_respond):
# Traceback (most recent call last):
#   File "C:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "C:\Users\LEGION\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\LEGION\AppData\Local\Temp\ipykernel_8220\1303010965.py", line 102, in recognize_and_respond
#   File "C:\Users\LEGION\AppData\Local\Temp\ipykernel_8220\1303010965.py", line 88, in enroll_user
# NameError: name 'get_input' is not defined

# %%
import tkinter as tk
from PIL import Image, ImageTk
import cv2
import threading
import speech_recognition as sr
import pyttsx3
import requests
import subprocess
import time
import winsound

recognizer = sr.Recognizer()
engine = pyttsx3.init()
playing_video = False

# Function to play video in Tkinter window
def play_video():
    global playing_video, cap
    if playing_video:
        ret, frame = cap.read()
        if ret:
            frame = cv2.resize(frame, (canvas_width, canvas_height))
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image = Image.fromarray(frame)
            image_tk = ImageTk.PhotoImage(image)
            canvas.create_image(0, 0, anchor=tk.NW, image=image_tk)
            canvas.image = image_tk
            root.after(10, play_video)
        else:
            cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
            play_video()

def start_video():
    global playing_video
    playing_video = True
    play_video()

def stop_video():
    global playing_video
    playing_video = False

def speak(text):
    engine.say(text)
    engine.runAndWait()

def play_listening_sound():
    winsound.PlaySound(r"C:\Users\LEGION\Downloads\voice-assistant-sound-name-unknown.wav", winsound.SND_FILENAME)

def recognize_speech():
    with sr.Microphone() as source:
        recognizer.adjust_for_ambient_noise(source)
        print("Listening for your question...")
        play_listening_sound()
        audio_data = recognizer.listen(source, timeout=300)
        try:
            question = recognizer.recognize_google(audio_data)
            print(f"You said: {question}")
            return question
        except sr.UnknownValueError:
            return None
        except sr.RequestError as e:
            print(f"Could not request results; {e}")
            return None

def communicate_with_rasa(question):
    url = "http://localhost:5005/webhooks/rest/webhook"
    payload = {"sender": "user", "message": question}
    response = requests.post(url, json=payload)
    if response.status_code == 200:
        bot_responses = response.json()
        if bot_responses:
            return bot_responses[0]['text']
    return "Sorry, I couldn't get a response from the server."

def run_rasa_shell():
    speak("Starting Rasa shell.")
    process = subprocess.Popen(["rasa", "run"], shell=True)
    time.sleep(5)
    speak("Rasa server is up and running.")
    return process

def get_input(prompt):
    speak(prompt)
    input_data = recognize_speech()
    return input_data

def enroll_user():
    speak("Hello, I will first ask for your phone number.")
    phone_number = get_input("Please say your phone number.")
    if phone_number:
        speak(f"You said: {phone_number}. Now I will ask for your email.")
        email = get_input("Please say your email address.")
        if email:
            speak(f"You said: {email}. What faculties are you chossing.")
            faculties=get_input("Please say your choice of faculty.")
            if faculties:
                speak(f"Thank you. You have been enrolled for {faculties} with phone number {phone_number}and email {email}.")
            else:
                speak("I couldn't understand your faculty. Please try again.")
        else:
            speak("I couldn't understand your email. Please try again.")
     else:
            speak("I couldn't understand your phone number. Please try again.")
def recognize_and_respond():
    while True:
        question = recognize_speech()
        if question:
            if "stop" in question.lower():
                speak("Stopping the program.")
                rasa_process.terminate()
                break
            elif "enroll" in question.lower():
                enroll_user()
            else:
                response = communicate_with_rasa(question)
                print(f"Bot: {response}")
                if "capture" in question.lower():
                    image_path = capture()
                    speak("Data has been saved to the database.")
                    if image_path:
                        ocr_result = ocr_scan(image_path)
                        speak(f"Scanned data: {ocr_result}")
                        insert_data_to_db(ocr_result['full_name'], ocr_result['citizenship_no'], "9876543210", ocr_result['address'], "something@gm.com", ocr_result['date_of_birth'], ocr_result['birth_place'], image_path)
                        speak("Data has been saved to the database.")
                else:
                    start_video()
                    speak(response)
                    stop_video()

root = tk.Tk()
root.title("Tkinter Chatbot")
canvas_width = 800
canvas_height = 600
root.geometry(f"{canvas_width}x{canvas_height}")

canvas = tk.Canvas(root, width=canvas_width, height=canvas_height)
canvas.pack()

cap = cv2.VideoCapture(r"C:\Users\LEGION\Desktop\New folder\Superlatives\captures\bot.webm")
rasa_process = run_rasa_shell()
recognize_thread = threading.Thread(target=recognize_and_respond)
recognize_thread.start()
start_video()
root.mainloop()
print("Program ended.")
# Out:
#   File <tokenize>:102
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level
