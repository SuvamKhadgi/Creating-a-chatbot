# %%
# !pip install torch torchvision torchaudio
# !pip install easyocr
# Out:
# Requirement already satisfied: torch in c:\python312\lib\site-packages (2.3.1)
# Requirement already satisfied: torchvision in c:\python312\lib\site-packages (0.18.1)
# Collecting torchaudio
#   Downloading torchaudio-2.3.1-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in c:\python312\lib\site-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\python312\lib\site-packages (from torch) (4.12.1)
# Requirement already satisfied: sympy in c:\python312\lib\site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in c:\python312\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\python312\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\python312\lib\site-packages (from torch) (2024.6.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\python312\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: numpy in c:\python312\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\python312\lib\site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\python312\lib\site-packages (from sympy->torch) (1.3.0)
# Downloading torchaudio-2.3.1-cp312-cp312-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.4 MB 186.2 kB/s eta 0:00:13
#     --------------------------------------- 0.0/2.4 MB 279.3 kB/s eta 0:00:09
#    - -------------------------------------- 0.1/2.4 MB 357.2 kB/s eta 0:00:07
#    -- ------------------------------------- 0.2/2.4 MB 655.4 kB/s eta 0:00:04
#    --- ------------------------------------ 0.2/2.4 MB 728.8 kB/s eta 0:00:03
#    ------ --------------------------------- 0.4/2.4 MB 1.0 MB/s eta 0:00:02
#    -------- ------------------------------- 0.5/2.4 MB 1.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.6/2.4 MB 1.4 MB/s eta 0:00:02
#    -------------- ------------------------- 0.9/2.4 MB 1.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.1/2.4 MB 2.0 MB/s eta 0:00:01
#    --------------------- ------------------ 1.3/2.4 MB 2.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.5/2.4 MB 2.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.4 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.9/2.4 MB 2.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.4 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 2.7 MB/s eta 0:00:00
# Installing collected packages: torchaudio
# Successfully installed torchaudio-2.3.1
# Requirement already satisfied: easyocr in c:\python312\lib\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\python312\lib\site-packages (from easyocr) (2.3.1)
# Requirement already satisfied: torchvision>=0.5 in c:\python312\lib\site-packages (from easyocr) (0.18.1)
# Requirement already satisfied: opencv-python-headless in c:\python312\lib\site-packages (from easyocr) (4.10.0.82)
# Requirement already satisfied: scipy in c:\python312\lib\site-packages (from easyocr) (1.13.1)
# Requirement already satisfied: numpy in c:\python312\lib\site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in c:\python312\lib\site-packages (from easyocr) (10.3.0)
# Requirement already satisfied: scikit-image in c:\python312\lib\site-packages (from easyocr) (0.23.2)
# Requirement already satisfied: python-bidi in c:\python312\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in c:\python312\lib\site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in c:\python312\lib\site-packages (from easyocr) (2.0.4)
# Requirement already satisfied: pyclipper in c:\python312\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\python312\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: filelock in c:\python312\lib\site-packages (from torch->easyocr) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\python312\lib\site-packages (from torch->easyocr) (4.12.1)
# Requirement already satisfied: sympy in c:\python312\lib\site-packages (from torch->easyocr) (1.12.1)
# Requirement already satisfied: networkx in c:\python312\lib\site-packages (from torch->easyocr) (3.3)
# Requirement already satisfied: jinja2 in c:\python312\lib\site-packages (from torch->easyocr) (3.1.4)
# Requirement already satisfied: fsspec in c:\python312\lib\site-packages (from torch->easyocr) (2024.6.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\python312\lib\site-packages (from torch->easyocr) (2021.4.0)
# Requirement already satisfied: six in c:\python312\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.33 in c:\python312\lib\site-packages (from scikit-image->easyocr) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\python312\lib\site-packages (from scikit-image->easyocr) (2024.5.22)
# Requirement already satisfied: packaging>=21 in c:\python312\lib\site-packages (from scikit-image->easyocr) (24.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\python312\lib\site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: intel-openmp==2021.* in c:\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python312\lib\site-packages (from jinja2->torch->easyocr) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\python312\lib\site-packages (from sympy->torch->easyocr) (1.3.0)

# %%
import cv2
import easyocr
from matplotlib import pyplot as plt
import numpy as np
import pyodbc
import os
import time
import pyodbc
import mysql.connector
import warnings
import speech_recognition as sr
import pyttsx3
from mysql.connector import Error
from PIL import Image
import base64

# %%
connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='cpktnwt',
    database='kisthack'
)
cursor = connection.cursor()

citizenship_no = None
full_name = None
date_of_birth = None
birth_place = None
address = None

# %%
def  capture():
    

    # Define the path where you want to save the video
    output_dir = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures' 
    img_path = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures/final_frame.jpg' 
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    image_file = os.path.join(output_dir, 'final_frame.jpg')
    output_file = os.path.join(output_dir, 'output.avi')
    
    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Use 'XVID' codec
    out = cv2.VideoWriter(output_file, fourcc, 20.0, (640, 480))
    
    # Open a connection to the webcam
    cap = cv2.VideoCapture(0)
    
    if not cap.isOpened():
        print("Error: Could not open video device")
        exit()
    
    # Set the width and height of the frame
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
    
    # Countdown duration in seconds
    countdown_duration = 10
    start_time = time.time()
    
    # Define the rectangle parameters
    top_left = (50, 50)
    bottom_right = (600, 400)
    color = (255, 0, 0)  # Blue color in BGR
    thickness = 2  # Thickness of the rectangle border
    
    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            # Draw the rectangle on the frame
            cv2.rectangle(frame, top_left, bottom_right, color, thickness)
    
            # Calculate the elapsed time and countdown value
            elapsed_time = time.time() - start_time
            countdown_value = max(0, countdown_duration - int(elapsed_time))
    
            # Define the countdown text and its position
            countdown_text = str(countdown_value)
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 2
            font_color = (0, 255, 0)  # Green color in BGR
            font_thickness = 3
            text_size = cv2.getTextSize(countdown_text, font, font_scale, font_thickness)[0]
            text_x = (top_left[0] + bottom_right[0] - text_size[0]) // 2
            text_y = (top_left[1] + bottom_right[1] + text_size[1]) // 2
    
            # Put the countdown text on the frame
            cv2.putText(frame, countdown_text, (text_x, text_y), font, font_scale, font_color, font_thickness)
    
            # Write the frame to the output file
            out.write(frame)
    
            # Display the frame
            cv2.imshow('frame', frame)
    
            # Break the loop on 'q' key press or when countdown reaches zero
            if cv2.waitKey(1) & 0xFF == ord('q') or countdown_value == 0:
                if countdown_value == 0:
                    # Save the last frame within the rectangle as an image
                    roi = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                    cv2.imwrite(image_file, roi)
                break
        else:
            break
    
    # Release the webcam and file writer
    cap.release()
    out.release()
    
    # Close all OpenCV windows
    cv2.destroyAllWindows()
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[48, 32], [976, 32], [976, 83], [48, 83]], 'Government of Nepal has issued this Citizenship Certificate with following details', 0.8429812531945474), ([[50, 80], [395, 80], [395, 117], [50, 117]], 'Citizenship Certificate No::', 0.9359731546771892), ([[428, 80], [626, 80], [626, 108], [428, 108]], '~23-01-78-01132', 0.5054853538093179), ([[886, 76], [1002, 76], [1002, 104], [886, 104]], 'Sex: Male', 0.9565622563752706), ([[54, 118], [204, 118], [204, 148], [54, 148]], 'Full Name:', 0.9983367996052408), ([[446, 111], [685, 111], [685, 148], [446, 148]], 'AYUSH ADHIKARI', 0.9859823092813841), ([[55, 151], [305, 151], [305, 187], [55, 187]], 'Date of Birth (AD):', 0.5429773182476133), ([[446, 147], [571, 147], [571, 183], [446, 183]], 'Year:2003', 0.7143760882563638), ([[678, 148], [828, 148], [828, 178], [678, 178]], 'Month:AUG', 0.8302417745554065), ([[883, 141], [976, 141], [976, 184], [883, 184]], 'Day.02', 0.608052975278368), ([[58, 190], [210, 190], [210, 220], [58, 220]], 'Birth Place:', 0.986035023909368), ([[446, 183], [669, 183], [669, 220], [446, 220]], 'District: RASUWA', 0.8113359386804198), ([[448, 222], [522, 222], [522, 252], [448, 252]], 'R M', 0.8537870784933166), ([[534, 222], [616, 222], [616, 252], [534, 252]], 'Kalika', 0.9999969339786576), ([[889, 211], [1029, 211], [1029, 247], [889, 247]], 'Ward No. 3', 0.6749844088232099), ([[58, 260], [316, 260], [316, 290], [58, 290]], 'Permanent Address:', 0.9294945637618539), ([[447, 253], [671, 253], [671, 289], [447, 289]], 'District: RASUWA', 0.9467448466656921), ([[450, 292], [522, 292], [522, 322], [450, 322]], 'R M', 0.9834671965498614), ([[534, 292], [616, 292], [616, 322], [534, 322]], 'Kalika', 0.999943935275836), ([[890, 284], [1028, 284], [1028, 314], [890, 314]], 'Ward No:3', 0.7991073298901179), ([[47, 337], [875, 337], [875, 381], [47, 381]], 'TTTATJaaTT3 ?o63 ThTa4 4 71IoaT yajutTfs0at€ |', 0.0004625299517719629), ([[47, 377], [343, 377], [343, 415], [47, 415]], 'TNJTRoafTA: &213t', 0.027699135424747705), ([[50, 418], [168, 418], [168, 444], [50, 444]], '9HTOT 9', 0.25508408561274465), ([[163, 410], [373, 410], [373, 451], [163, 451]], "'314+2rOT", 0.0087916538692837), ([[50, 448], [128, 448], [128, 480], [50, 480]], '(T)', 0.6973453583556263), ([[141, 443], [292, 443], [292, 479], [141, 479]], '3315t UTY', 0.10981816316827842), ([[310, 448], [388, 448], [388, 480], [310, 480]], '(TT4)', 0.3238425384109797), ([[659, 499], [999, 499], [999, 539], [659, 539]], 'YATO W7 JrJA 3e7r0+j', 0.0010857733413266871), ([[660, 552], [770, 552], [770, 578], [660, 578]], 'ZFTQT :', 0.22230354641687697), ([[662, 582], [756, 582], [756, 612], [662, 612]], 'T*', 0.16393441430527475), ([[750, 568], [930, 568], [930, 622], [750, 622]], '3iu9%#', 0.013364742577380047), ([[658, 599], [1058, 599], [1058, 649], [658, 649]], 'ar 4645 5jG Talait 3ern8', 0.003234956672396247), ([[659, 641], [929, 641], [929, 680], [659, 680]], 'JrTa: Ro02-o8-?8', 0.06314402920327242), ([[231, 727], [375, 727], [375, 765], [231, 765]], 'Iait 9NTQAT :', 0.01293626039794195), ([[519, 713], [863, 713], [863, 749], [519, 749]], 'RIRT #Turrun a6,4r0 TFuirrat', 0.007989866230513773), ([[854, 706], [989, 706], [989, 751], [854, 751]], '37137z61a1', 0.032785033833421816), ([[971.8786796564403, 544.8786796564403], [1072.7124261605081, 528.7183041219577], [1077.1213203435595, 559.1213203435597], [976.2875738394918, 574.2816958780423]], '72', 0.45931425935466313), ([[1165.5880596277889, 591.5061358188523], [1207.4105330947973, 626.4065213264607], [1116.4119403722111, 725.4938641811477], [1075.5894669052027, 689.5934786735393]], '1', 0.365518183651389), ([[1020.1579833204635, 744.2897482934367], [1084.9347727505294, 683.3205057968329], [1114.8420166795365, 724.7102517065633], [1050.0652272494706, 785.6794942031671]], 'Fa', 0.10410729567218943)]

# %%
capture()
# Out:
# Government of Nepal has issued this Citizenship Certificate with following details
# Citizenship Certificate No::
# ~23-01-78-01132
# Sex: Male
# Full Name:
# AYUSH ADHIKARI
# Date of Birth (AD):
# Year:2003
# Month:AUG
# Day.02
# Birth Place:
# District: RASUWA
# R M
# Kalika
# Ward No. 3
# Permanent Address:
# District: RASUWA
# R M
# Kalika
# Ward No:3
# TTTATJaaTT3 ?o63 ThTa4 4 71IoaT yajutTfs0at€ |
# TNJTRoafTA: &213t
# 9HTOT 9
# '314+2rOT
# (T)
# 3315t UTY
# (TT4)
# YATO W7 JrJA 3e7r0+j
# ZFTQT :
# T*
# 3iu9%#
# ar 4645 5jG Talait 3ern8
# JrTa: Ro02-o8-?8
# Iait 9NTQAT :
# RIRT #Turrun a6,4r0 TFuirrat
# 37137z61a1
# 72
# 1
# Fa
# Citizenship No: 23-01-78-01132
# Full Name: AYUSH ADHIKARI
# Date of Birth: 2003 AUG 02
# Birth Place: Kalika- 3,RASUWA
# Permanent Address: Kalika-:3,RASUWA

# %%
img_path = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures/final_frame.jpg'

# %%
capture()

# %%
def ocrscnphoto():
    print()
    
citizenship_no = "17-01-77-05501"
full_name = "ASHOK SHAH"
date_of_birth = "2003 SEP 26"
birth_place = "Sonigama - 2,Dhanusha"
address = "Hansapur - 9,Dhanusha"

# %%
def ocrscanphoto():
    img_path = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures/final_frame.jpg'
    reader = easyocr.Reader(['en'], gpu = False)
    text = reader.readtext(img_path)
    
    
    print(text)
    
    
    
    
    # Initialize an empty list to store the extracted strings
    extracted_strings = []
    
    # Iterate over each tuple in processed_data
    for item in text:
        # Extract the text from the tuple and append it to the list
        extracted_strings.append(item[1])
    
    # Print the extracted strings
    for string in extracted_strings:
        print(string)
    
    
    citizenship_no = extracted_strings[2][1:]
    sex = extracted_strings[3][5:]
    full_name = extracted_strings[5]
    date_of_birth = extracted_strings[7][-4:]+ " "+ extracted_strings[8][-3:]+ " "+ extracted_strings[9][-2:] 
    birth_place = extracted_strings[13]+ "-"+ extracted_strings[14][-2:]+ ","+ extracted_strings[11][10:]
    address = extracted_strings[18]+ "-"+ extracted_strings[19][-2:]+ ","+ extracted_strings[16][10:]

# %%
ocrscnphoto()

# %%
image_path = 'C:/Users/subad/OneDrive/Desktop/computer vision/resources/back.jpg'

# %%
def prescanned():
    
    img = cv2.imread(image_path)
    
    reader = easyocr.Reader(['en'], gpu = True)
    text = reader.readtext(image_path)
    print(text)# Initialize an empty list to store the extracted strings
    extracted_strings = []
    
    # Iterate over each tuple in processed_data
    for item in text:
        # Extract the text from the tuple and append it to the list
        extracted_strings.append(item[1])
    
    # Print the extracted strings
    # for string in extracted_strings:
        # print(string)
    
    
    citizenship_no = extracted_strings[2][1:]
    sex = extracted_strings[3][5:]
    full_name = extracted_strings[5]
    date_of_birth = extracted_strings[7][-4:]+ " "+ extracted_strings[8][-3:]+ " "+ extracted_strings[9][-2:] 
    birth_place = extracted_strings[13]+ "-"+ extracted_strings[14][-2:]+ ","+ extracted_strings[11][10:]
    address = extracted_strings[18]+ "-"+ extracted_strings[19][-2:]+ ","+ extracted_strings[16][10:]
    
    
    print()
    print()
    print()
    # Print the extracted information
    print(f"Citizenship No: {citizenship_no}")
    print(f"Full Name: {full_name}")
    print(f"Date of Birth: {date_of_birth}")
    print(f"Birth Place: {birth_place}")
    print(f"Permanent Address: {address}")

# %%
img_path = 'C:/Users/subad/OneDrive/Desktop/New folder (2)/Superlatives/captures/final_frame.jpg'

# %%
print(f"Citizenship No: {citizenship_no}")
print(f"Full Name: {full_name}")
print(f"Date of Birth: {date_of_birth}")
print(f"Birth Place: {birth_place}")
print(f"Permanent Address: {address}")

# %%
email = "something@gm.com"
number = "9876543210"
# Out:
# [([[48, 32], [976, 32], [976, 83], [48, 83]], 'Government of Nepal has issued this Citizenship Certificate with following details', 0.8702033242202902), ([[50, 80], [395, 80], [395, 117], [50, 117]], 'Citizenship Certificate No::', 0.9435435885952961), ([[428, 80], [626, 80], [626, 108], [428, 108]], '-23-01-78-01132', 0.5052038089546481), ([[886, 76], [1002, 76], [1002, 104], [886, 104]], 'Sex: Male', 0.9533030997231765), ([[54, 118], [204, 118], [204, 148], [54, 148]], 'Full Name:', 0.9982310077718768), ([[446, 111], [685, 111], [685, 148], [446, 148]], 'AYUSH ADHIKARI', 0.9812006555286804), ([[55, 151], [305, 151], [305, 187], [55, 187]], 'Date of Birth (AD):', 0.6438545187635621), ([[448, 150], [570, 150], [570, 180], [448, 180]], 'Year:2003', 0.9384601961468284), ([[678, 148], [828, 148], [828, 178], [678, 178]], 'Month:AUG', 0.8293397623491812), ([[883, 141], [976, 141], [976, 184], [883, 184]], 'Day.02', 0.576925912960357), ([[58, 190], [210, 190], [210, 220], [58, 220]], 'Birth Place:', 0.9897808070125579), ([[446, 183], [669, 183], [669, 220], [446, 220]], 'District: RASUWA', 0.8377583049839634), ([[448, 222], [522, 222], [522, 252], [448, 252]], 'R M', 0.8779944572189177), ([[534, 222], [616, 222], [616, 252], [534, 252]], 'Kalika', 0.99999669064354), ([[889, 211], [1027, 211], [1027, 247], [889, 247]], 'Ward No. 3', 0.5949198843572439), ([[58, 260], [316, 260], [316, 290], [58, 290]], 'Permanent Address:', 0.9253739739719657), ([[447, 253], [671, 253], [671, 289], [447, 289]], 'District: RASUWA', 0.9542441101764498), ([[450, 292], [522, 292], [522, 322], [450, 322]], 'R M', 0.9837762955751234), ([[534, 292], [616, 292], [616, 322], [534, 322]], 'Kalika', 0.9999471960039688), ([[890, 284], [1028, 284], [1028, 314], [890, 314]], 'Ward No:.3', 0.46586972579021335)]

# %%
def insertdata():
    connection = mysql.connector.connect(
        host='localhost',
        user='root',
        password='cpktnwt',
        database='kisthack'
    )
    cursor = connection.cursor()
    
    sql_insert_base64_query = """ INSERT INTO student
                                      ( name, citizenship_number, number, address, email, DOB, birthplace, photo) 
                                      VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"""
    
            
    with open(image_path, 'rb') as image_file:
        base64_image = base64.b64encode(image_file.read()).decode('utf-8')
    
            # Convert data into tuple format
    insert_base64_tuple = ( full_name, citizenship_no, number, address, email, date_of_birth, birth_place, base64_image)
    cursor.execute(sql_insert_base64_query, insert_base64_tuple)
    connection.commit()
    
    print("Record inserted successfully")

# %%
insertdata()

# %%
cursor.execute("SELECT * FROM student")
result = cursor.fetchall()

for row in result:
    print(row)
